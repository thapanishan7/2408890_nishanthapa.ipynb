# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

#1) loading data and displaying the first ten rows from the dataset
dataset =pd.read_csv('/content/WHR-2024-5CS037.csv')
print("the first ten roes of the data set")
#using .head method to retrive the rows
print(dataset.head(10))

#2) identifying the number of rows and cols in dataset
#.shape method retrives the numbers of rows and columns
rows,columns =dataset.shape
print(f"\nThe dataset has {rows} rows and {columns} columns.")

#3) listing all the columns and their data types
print("\nColumns and their data types:")
print(dataset.dtypes)


#basic statistics

mean_score=dataset['score'].mean()
medain_score=dataset['score'].median()
std_dev_score=dataset['score'].std()

print(f"\nMean Score: {mean_score}")
print(f"Median Score: {medain_score}")
print(f"Standard Deviation of Score: {std_dev_score}")

#identifying the country with highest and lowest happiness
max_happiness_country=dataset.loc[dataset['score'].idxmax()]
min_happiness_country=dataset.loc[dataset['score'].idxmin()]

print(f"\nCountry with the Highest Score: {max_happiness_country['Country name']} (Score: {max_happiness_country['score']})")
print(f"Country with the Lowest Score: {min_happiness_country['Country name']} (Score: {min_happiness_country['score']})")

#checking missing values in the dataset

missing_values=dataset.isnull().sum()
print("\nMissing Values in Each Column:")
print(missing_values)

#filtering and sorting the datasets

filtered_dataset=dataset[dataset["score"]>7.5]
#sorting the filtered dataset by gdp per ascending order
sorted_dataset=filtered_dataset.sort_values(by="Log GDP per capita",ascending=False)
#displaying top 10 rows
top_10_rows = sorted_dataset.head(10)

print("Top 10 rows of the filtered and sorted dataset:")
print(top_10_rows)

#creating a new column happiness category based on the conditions
def categorize_happiness(score):
    if score < 4:
        return "low"
    elif 4 <= score <=6:
        return "medium"
    else:
        return " high "
dataset['happiness category']=dataset['score'].apply(categorize_happiness)
#displaying the updated dataset
print(dataset[['Country name','score','happiness category']])
#

import matplotlib.pyplot as plt
import seaborn as sns

#1) loading data and displaying the first ten rows from the dataset
dataset =pd.read_csv('/content/WHR-2024-5CS037.csv')
print("the first ten roes of the data set")
#using .head method to retrive the rows
print(dataset.head(10))

#2) identifying the number of rows and cols in dataset
#.shape method retrives the numbers of rows and columns
rows,columns =dataset.shape
print(f"\nThe dataset has {rows} rows and {columns} columns.")

#3) listing all the columns and their data types
print("\nColumns and their data types:")
print(dataset.dtypes)


#basic statistics

mean_score=dataset['score'].mean()
medain_score=dataset['score'].median()
std_dev_score=dataset['score'].std()

print(f"\nMean Score: {mean_score}")
print(f"Median Score: {medain_score}")
print(f"Standard Deviation of Score: {std_dev_score}")

#identifying the country with highest and lowest happiness
max_happiness_country=dataset.loc[dataset['score'].idxmax()]
min_happiness_country=dataset.loc[dataset['score'].idxmin()]

print(f"\nCountry with the Highest Score: {max_happiness_country['Country name']} (Score: {max_happiness_country['score']})")
print(f"Country with the Lowest Score: {min_happiness_country['Country name']} (Score: {min_happiness_country['score']})")

#checking missing values in the dataset

missing_values=dataset.isnull().sum()
print("\nMissing Values in Each Column:")
print(missing_values)

#filtering and sorting the datasets

filtered_dataset=dataset[dataset["score"]>7.5]
#sorting the filtered dataset by gdp per ascending order
sorted_dataset=filtered_dataset.sort_values(by="Log GDP per capita",ascending=False)
#displaying top 10 rows
top_10_rows = sorted_dataset.head(10)

print("Top 10 rows of the filtered and sorted dataset:")
print(top_10_rows)

#creating a new column happiness category based on the conditions
def categorize_happiness(score):
    if score < 4:
        return "low"
    elif 4 <= score <=6:
        return "medium"
    else:
        return " high "
dataset['happiness category']=dataset['score'].apply(categorize_happiness)
#displaying the updated dataset
print(dataset[['Country name','score','happiness category']])
#
top_10_happiest = dataset.nlargest(10, 'score')
plt.figure(figsize=(10, 6))
sns.barplot(data=top_10_happiest, x='score', y='Country name', palette='viridis') #Fixed typo here
plt.title('Top 10 Happiest Countries by Score')
plt.xlabel('Happiness Score')
plt.ylabel('Country')
plt.show()

# Line Plot: Top 10 Unhappiest Countries by Score
top_10_unhappiest = dataset.nsmallest(10, 'score') #Fixed typo here: 'Score' to 'score'
plt.figure(figsize=(10, 6))
plt.plot(top_10_unhappiest['Country name'], top_10_unhappiest['score'], marker='o', color='red') #Fixed column name
plt.title('Top 10 Unhappiest Countries by Score')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.xticks(rotation=45)
plt.show()

# Histogram: Distribution of the Score column
plt.figure(figsize=(10, 6))
plt.hist(dataset['score'], bins=15, color='blue', alpha=0.7, edgecolor='black') #Fixed column name
plt.title('Distribution of Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.show()

# Scatter Plot: GDP per Capita vs. Score
plt.figure(figsize=(10, 6))
sns.scatterplot(data=dataset, x='Log GDP per capita', y='score', hue='happiness category', palette='coolwarm') #Fixed column names
plt.title('Relationship between GDP per Capita and Happiness Score')
plt.xlabel('GDP per Capita')
plt.ylabel('Happiness Score')
plt.legend(title='Happiness Category')
plt.show()
plt.ylabel('Country')
plt.show()

# Line Plot: Top 10 Unhappiest Countries by Score
top_10_unhappiest = dataset.nsmallest(10, 'score')
plt.figure(figsize=(10, 6))
plt.plot(top_10_unhappiest['Country name'], top_10_unhappiest['score'], marker='o', color='red')
plt.title('Top 10 Unhappiest Countries by Score')
plt.xlabel('Country')
plt.ylabel('Happiness Score')
plt.xticks(rotation=45)
plt.show()

# Histogram: Distribution of the Score column
plt.figure(figsize=(10, 6))
plt.hist(dataset['score'], bins=15, color='blue', alpha=0.7, edgecolor='black')
plt.title('Distribution of Happiness Scores')
plt.xlabel('Happiness Score')
plt.ylabel('Frequency')
plt.show()

# Scatter Plot: GDP per Capita vs. Score
plt.figure(figsize=(10, 6))
sns.scatterplot(data=dataset, x='Log GDP per capita', y='score', hue='happiness category', palette='coolwarm')
plt.title('Relationship between GDP per Capita and Happiness Score')
plt.xlabel('GDP per Capita')
plt.ylabel('Happiness Score')
plt.legend(title='Happiness Category')
plt.show()


# South Asia countries (example, you may need to adjust the list)
#Task2

# South Asia countries (example, you may need to adjust the list)
south_asia = ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']

# Filter the dataset for South Asian countries
# Replace 'Country name' with the actual column name from your dataframe
south_asia_df = dataset[dataset['Country name'].isin(south_asia)]  # Changed 'Country' to 'Country name'

# Save to new CSV
south_asia_df.to_csv("south_asia_happiness.csv", index=False)

print(south_asia_df.head())




#Task3

## South Asia countries (example, you may need to adjust the list)
south_asia = ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']

# Filter the dataset for South Asian countries
# Replace 'Country name' with the actual column name from your dataframe if it's different
south_asia_df = dataset[dataset['Country name'].isin(south_asia)]  # Changed 'Country' to 'Country name'

# Save to new CSV
south_asia_df.to_csv("south_asia_happiness.csv", index=False)

print(south_asia_df.head())


#4
# South Asia countries (example, you may need to adjust the list)
south_asia = ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']

# Filter the dataset for South Asian countries
# Replace 'Country' with the actual column name from your dataframe, likely 'Country name'
south_asia_df = dataset[dataset['Country name'].isin(south_asia)]  # Changed 'Country' to 'Country name'

# Save to new CSV
south_asia_df.to_csv("south_asia_happiness.csv", index=False)

print(south_asia_df.head())





#5
# South Asia countries (example, you may need to adjust the list)
south_asia = ['Afghanistan', 'Bangladesh', 'Bhutan', 'India', 'Maldives', 'Nepal', 'Pakistan', 'Sri Lanka']

# Filter the dataset for South Asian countries
# Changed 'Country' to 'Country name' to match the actual column name
south_asia_df = dataset[dataset['Country name'].isin(south_asia)]

# Save to new CSV
south_asia_df.to_csv("south_asia_happiness.csv", index=False)

print(south_asia_df.head())




#6
# Calculate GDP-Score Gap
# Replace 'GDP per Capita' with the correct column name from your DataFrame, likely 'Log GDP per capita'
dataset['GDP-Score Gap'] = dataset['Log GDP per capita'] - dataset['score']

# Rank by GDP-Score Gap
df_sorted_gap = dataset.sort_values(by='GDP-Score Gap', ascending=False)

# Bar chart for top 3 positive and negative gaps
top_positive_gap = df_sorted_gap.head(3)
top_negative_gap = df_sorted_gap.tail(3)

plt.figure(figsize=(10, 6))
# Replace 'Country' with the actual column name for country, likely 'Country name'
sns.barplot(x='GDP-Score Gap', y='Country name', data=pd.concat([top_positive_gap, top_negative_gap]))
plt.title("Top 3 Positive and Negative GDP-Score Gaps")
plt.show()




#7
## Middle Eastern countries (example)
middle_east = ['Bahrain', 'Egypt', 'Iran', 'Iraq', 'Israel', 'Jordan', 'Kuwait', 'Lebanon', 'Oman', 'Qatar', 'Saudi Arabia', 'Syria', 'United Arab Emirates', 'Yemen']

# Filter the dataset for Middle Eastern countries
# Changed 'Country' to 'Country name' to match the actual column name in the DataFrame
middle_east_df = dataset[dataset['Country name'].isin(middle_east)]

# Descriptive statistics for both regions
# Changed 'Score' to 'score' to match the actual column name
south_asia_mean = south_asia_df['score'].mean()
middle_east_mean = middle_east_df['score'].mean()

south_asia_std = south_asia_df['score'].std()
middle_east_std = middle_east_df['score'].std()

print(f"South Asia - Mean Score: {south_asia_mean}, Standard Deviation: {south_asia_std}")
print(f"Middle East - Mean Score: {middle_east_mean}, Standard Deviation: {middle_east_std}")

# Top and Bottom performers
top_3_sa = south_asia_df.head(3)
bottom_3_sa = south_asia_df.tail(3)

top_3_me = middle_east_df.head(3)
bottom_3_me = middle_east_df.tail(3)

# Visualization (bar charts)
plt.figure(figsize=(10, 6))
# Changed 'Score' to 'score' and 'Country' to 'Country name'
sns.barplot(x='score', y='Country name', data=pd.concat([top_3_sa, top_3_me]))
plt.title("Top 3 Performers - South Asia vs Middle East")
plt.show()

plt.figure(figsize=(10, 6))
# Changed 'Score' to 'score' and 'Country' to 'Country name'
sns.barplot(x='score', y='Country name', data=pd.concat([bottom_3_sa, bottom_3_me]))
plt.title("Bottom 3 Performers - South Asia vs Middle East")
plt.show()
# Out:
# the first ten roes of the data set
#   Country name  score  Log GDP per capita  Social support  \
# 0      Finland  7.741               1.844           1.572
# 1      Denmark  7.583               1.908           1.520
# 2      Iceland  7.525               1.881           1.617
# 3       Sweden  7.344               1.878           1.501
# 4       Israel  7.341               1.803           1.513
# 5  Netherlands  7.319               1.901           1.462
# 6       Norway  7.302               1.952           1.517
# 7   Luxembourg  7.122               2.141           1.355
# 8  Switzerland  7.060               1.970           1.425
# 9    Australia  7.057               1.854           1.461
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.695                         0.859       0.142
# 1                    0.699                         0.823       0.204
# 2                    0.718                         0.819       0.258
# ...
